# %%
import urllib.parse
import requests
from datetime import date
import datetime

# %%
now = datetime.datetime.now()
date=now.date()
time=now.time()
print(now,date,time)
# Out:
# 2022-09-06 09:52:02.734157 2022-09-06 09:52:02.734157

# %%
def time_until_end_of_day(dt=None):
    if dt is None:
        dt = now.time()
    return (((24 - dt.hour - 1) * 60 * 60) + ((60 - dt.minute - 1) * 60)) //3600

# %%
time_until_end_of_day()
# Out:
# 14

# %%
def choose_n()
if time_until_end_of_day>=24
    n=0
elif time_until_end_of_day >= 15
    n=0
elif time_until_end_of_day >= 12
    n=1
elif time_until_end_of_day >= 9
    n=2
elif time_until_end_of_day >= 6
    n=3
elif time_until_end_of_day >= 3
    n=4
elif time_until_end_of_day >=0
    n=5
# Out:
# 13

# %%
BASE_URL = "https://weather.lewagon.com"
def weather_forecast():
    '''Return a 5-day weather forecast for the city, given its latitude and longitude.'''
    url = BASE_URL+f"/data/2.5/forecast?lat=40.4167047&lon=-3.703582&units=metric"

    response = requests.get(url).json()

    return response
lat = 40.4167047
lon = -3.703582

# %%
today = date.today()
#date_requested = input_from_website
date_requested = date(2022,9,7)

# %%
delta = date_requested-today
# Out:
# datetime.timedelta(days=1)

# %%
if delta.days < 4
    try:
     forecast = weather_forecast()
     feels_like = response["list"][delta.days*8+n]["main"]["feels_like"]
     weather = response["list"][delta.days*8+n]["weather"][0]["main"]
    except:
            if month in [January, December]
        weather = Cloudy
        feels_like = dict[month]
    else
        weather == Sunny
        feels_like = dict[month]

# %%
response = weather_forecast()

# %%
response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1662454800,
#    'main': {'temp': 19.15,
#     'feels_like': 18.56,
#     'temp_min': 19.15,
#     'temp_max': 21.32,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 944,
#     'humidity': 55,
#     'temp_kf': -2.17},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 3.3, 'deg': 229, 'gust': 4.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 09:00:00'},
#   {'dt': 1662465600,
#    'main': {'temp': 23.1,
#     'feels_like': 22.56,
#     'temp_min': 23.1,
#     'temp_max': 25.61,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 944,
#     'humidity': 42,
#     'temp_kf': -2.51},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 5.87, 'deg': 233, 'gust': 7.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 12:00:00'},
#   {'dt': 1662476400,
#    'main': {'temp': 27.69,
#     'feels_like': 26.75,
#     'temp_min': 27.69,
#     'temp_max': 27.69,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 6.78, 'deg': 234, 'gust': 8.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 15:00:00'},
#   {'dt': 1662487200,
#    'main': {'temp': 26.28,
#     'feels_like': 26.28,
#     'temp_min': 26.28,
#     'temp_max': 26.28,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 6.13, 'deg': 237, 'gust': 7.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 18:00:00'},
#   {'dt': 1662498000,
#    'main': {'temp': 22.97,
#     'feels_like': 22.18,
#     'temp_min': 22.97,
#     'temp_max': 22.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 4.29, 'deg': 240, 'gust': 7.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-06 21:00:00'},
#   {'dt': 1662508800,
#    'main': {'temp': 21.62,
#     'feels_like': 20.65,
#     'temp_min': 21.62,
#     'temp_max': 21.62,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.96, 'deg': 261, 'gust': 5.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 00:00:00'},
#   {'dt': 1662519600,
#    'main': {'temp': 19.67,
#     'feels_like': 18.61,
#     'temp_min': 19.67,
#     'temp_max': 19.67,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 1.56, 'deg': 237, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 03:00:00'},
#   {'dt': 1662530400,
#    'main': {'temp': 18.1,
#     'feels_like': 17.01,
#     'temp_min': 18.1,
#     'temp_max': 18.1,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 1.04, 'deg': 195, 'gust': 1.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 06:00:00'},
#   {'dt': 1662541200,
#    'main': {'temp': 21.2,
#     'feels_like': 20.26,
#     'temp_min': 21.2,
#     'temp_max': 21.2,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 3.12, 'deg': 224, 'gust': 5.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 09:00:00'},
#   {'dt': 1662552000,
#    'main': {'temp': 22.01,
#     'feels_like': 20.95,
#     'temp_min': 22.01,
#     'temp_max': 22.01,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 5.1, 'deg': 236, 'gust': 6.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 12:00:00'},
#   {'dt': 1662562800,
#    'main': {'temp': 25.96,
#     'feels_like': 25.96,
#     'temp_min': 25.96,
#     'temp_max': 25.96,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.94, 'deg': 233, 'gust': 6.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 15:00:00'},
#   {'dt': 1662573600,
#    'main': {'temp': 25.05,
#     'feels_like': 24.13,
#     'temp_min': 25.05,
#     'temp_max': 25.05,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.12, 'deg': 246, 'gust': 6.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 18:00:00'},
#   {'dt': 1662584400,
#    'main': {'temp': 22.3,
#     'feels_like': 21.4,
#     'temp_min': 22.3,
#     'temp_max': 22.3,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 940,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 3.45, 'deg': 302, 'gust': 5.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 21:00:00'},
#   {'dt': 1662595200,
#    'main': {'temp': 20.61,
#     'feels_like': 19.69,
#     'temp_min': 20.61,
#     'temp_max': 20.61,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 0.78, 'deg': 284, 'gust': 1.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 00:00:00'},
#   {'dt': 1662606000,
#    'main': {'temp': 18.47,
#     'feels_like': 17.5,
#     'temp_min': 18.47,
#     'temp_max': 18.47,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 1.31, 'deg': 54, 'gust': 1.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 03:00:00'},
#   {'dt': 1662616800,
#    'main': {'temp': 17.8,
#     'feels_like': 16.84,
#     'temp_min': 17.8,
#     'temp_max': 17.8,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 1.57, 'deg': 44, 'gust': 1.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 06:00:00'},
#   {'dt': 1662627600,
#    'main': {'temp': 20.91,
#     'feels_like': 20.02,
#     'temp_min': 20.91,
#     'temp_max': 20.91,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.77, 'deg': 66, 'gust': 1.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 09:00:00'},
#   {'dt': 1662638400,
#    'main': {'temp': 24.58,
#     'feels_like': 23.9,
#     'temp_min': 24.58,
#     'temp_max': 24.58,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.56, 'deg': 217, 'gust': 2.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 12:00:00'},
#   {'dt': 1662649200,
#    'main': {'temp': 27.73,
#     'feels_like': 26.74,
#     'temp_min': 27.73,
#     'temp_max': 27.73,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 3.81, 'deg': 205, 'gust': 4.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 15:00:00'},
#   {'dt': 1662660000,
#    'main': {'temp': 27.19,
#     'feels_like': 26.46,
#     'temp_min': 27.19,
#     'temp_max': 27.19,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 38},
#    'wind': {'speed': 3.34, 'deg': 235, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 18:00:00'},
#   {'dt': 1662670800,
#    'main': {'temp': 24.7,
#     'feels_like': 24.01,
#     'temp_min': 24.7,
#     'temp_max': 24.7,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 3.01, 'deg': 307, 'gust': 4.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 21:00:00'},
#   {'dt': 1662681600,
#    'main': {'temp': 22.81,
#     'feels_like': 22.01,
#     'temp_min': 22.81,
#     'temp_max': 22.81,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 1.04, 'deg': 14, 'gust': 1.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 00:00:00'},
#   {'dt': 1662692400,
#    'main': {'temp': 20.88,
#     'feels_like': 19.96,
#     'temp_min': 20.88,
#     'temp_max': 20.88,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.09, 'deg': 55, 'gust': 1.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 03:00:00'},
#   {'dt': 1662703200,
#    'main': {'temp': 19.74,
#     'feels_like': 18.81,
#     'temp_min': 19.74,
#     'temp_max': 19.74,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 942,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 1.6, 'deg': 55, 'gust': 1.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 06:00:00'},
#   {'dt': 1662714000,
#    'main': {'temp': 23.62,
#     'feels_like': 22.87,
#     'temp_min': 23.62,
#     'temp_max': 23.62,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 944,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 1.33, 'deg': 55, 'gust': 1.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 09:00:00'},
#   {'dt': 1662724800,
#    'main': {'temp': 27.69,
#     'feels_like': 26.75,
#     'temp_min': 27.69,
#     'temp_max': 27.69,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 1.1, 'deg': 230, 'gust': 2.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 12:00:00'},
#   {'dt': 1662735600,
#    'main': {'temp': 30.81,
#     'feels_like': 28.95,
#     'temp_min': 30.81,
#     'temp_max': 30.81,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 943,
#     'humidity': 21,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 2.79, 'deg': 204, 'gust': 4.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 15:00:00'},
#   {'dt': 1662746400,
#    'main': {'temp': 30.17,
#     'feels_like': 28.38,
#     'temp_min': 30.17,
#     'temp_max': 30.17,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 942,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 2.08, 'deg': 252, 'gust': 3.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 18:00:00'},
#   {'dt': 1662757200,
#    'main': {'temp': 26.73,
#     'feels_like': 26.11,
#     'temp_min': 26.73,
#     'temp_max': 26.73,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.22, 'deg': 344, 'gust': 1.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 21:00:00'},
#   {'dt': 1662768000,
#    'main': {'temp': 24.13,
#     'feels_like': 23.3,
#     'temp_min': 24.13,
#     'temp_max': 24.13,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 4.1, 'deg': 49, 'gust': 7.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-10 00:00:00'},
#   {'dt': 1662778800,
#    'main': {'temp': 22.1,
#     'feels_like': 21.23,
#     'temp_min': 22.1,
#     'temp_max': 22.1,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 3.67, 'deg': 40, 'gust': 5.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-10 03:00:00'},
#   {'dt': 1662789600,
#    'main': {'temp': 20.98,
#     'feels_like': 20.07,
#     'temp_min': 20.98,
#     'temp_max': 20.98,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.93, 'deg': 51, 'gust': 3.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-10 06:00:00'},
#   {'dt': 1662800400,
#    'main': {'temp': 25.03,
#     'feels_like': 24.37,
#     'temp_min': 25.03,
#     'temp_max': 25.03,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 1.94, 'deg': 83, 'gust': 2.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-10 09:00:00'},
#   {'dt': 1662811200,
#    'main': {'temp': 30.17,
#     'feels_like': 28.49,
#     'temp_min': 30.17,
#     'temp_max': 30.17,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 944,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 1.52, 'deg': 203, 'gust': 2.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-10 12:00:00'},
#   {'dt': 1662822000,
#    'main': {'temp': 32.82,
#     'feels_like': 30.76,
#     'temp_min': 32.82,
#     'temp_max': 32.82,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 942,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.96, 'deg': 234, 'gust': 4.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-10 15:00:00'},
#   {'dt': 1662832800,
#    'main': {'temp': 32.12,
#     'feels_like': 30.09,
#     'temp_min': 32.12,
#     'temp_max': 32.12,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 941,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 2.79, 'deg': 245, 'gust': 3.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-10 18:00:00'},
#   {'dt': 1662843600,
#    'main': {'temp': 29.11,
#     'feels_like': 27.63,
#     'temp_min': 29.11,
#     'temp_max': 29.11,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 941,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.42, 'deg': 228, 'gust': 4.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-10 21:00:00'},
#   {'dt': 1662854400,
#    'main': {'temp': 26.96,
#     'feels_like': 26.25,
#     'temp_min': 26.96,
#     'temp_max': 26.96,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.23, 'deg': 255, 'gust': 1.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-11 00:00:00'},
#   {'dt': 1662865200,
#    'main': {'temp': 24.56,
#     'feels_like': 23.88,
#     'temp_min': 24.56,
#     'temp_max': 24.56,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.66, 'deg': 178, 'gust': 1.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-11 03:00:00'},
#   {'dt': 1662876000,
#    'main': {'temp': 22.85,
#     'feels_like': 22.13,
#     'temp_min': 22.85,
#     'temp_max': 22.85,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.03, 'deg': 143, 'gust': 1.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-11 06:00:00'}],
#  'city': {'id': 6545083,
#   'name': 'Sol',
#   'coord': {'lat': 40.4167, 'lon': -3.7036},
#   'country': 'ES',
#   'population': 0,
#   'timezone': 7200,
#   'sunrise': 1662443214,
#   'sunset': 1662489599}}

# %%
feels_like = response["list"][delta.days*8]
#weather = response["list"][delta.days*8]["weather"][0]["main"]
feels_like
# Out:
# {'dt': 1662541200,
#  'main': {'temp': 21.2,
#   'feels_like': 20.26,
#   'temp_min': 21.2,
#   'temp_max': 21.2,
#   'pressure': 1016,
#   'sea_level': 1016,
#   'grnd_level': 941,
#   'humidity': 34,
#   'temp_kf': 0},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 86},
#  'wind': {'speed': 3.12, 'deg': 224, 'gust': 5.02},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2022-09-07 09:00:00'}

# %%
change the time and date asked to match the response

# %%
response["list"][0]
# Out:
# {'dt': 1662454800,
#  'main': {'temp': 19.15,
#   'feels_like': 18.56,
#   'temp_min': 19.15,
#   'temp_max': 21.32,
#   'pressure': 1021,
#   'sea_level': 1021,
#   'grnd_level': 944,
#   'humidity': 55,
#   'temp_kf': -2.17},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'clouds': {'all': 5},
#  'wind': {'speed': 3.3, 'deg': 229, 'gust': 4.49},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2022-09-06 09:00:00'}
