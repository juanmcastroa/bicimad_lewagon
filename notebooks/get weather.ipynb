# %%
import sys
from unicodedata import name
import urllib.parse
import requests
from sklearn.metrics import mean_absolute_error

# %%
BASE_URL = "https://weather.lewagon.com"

# %%
lat = 40.4167047
lon = -3.7035825

# %%
def weather_forecast(lat, lon):
    '''Return a 5-day weather forecast for the city, given its latitude and longitude.'''
    url = BASE_URL+f"/data/2.5/forecast?lat={lat}&lon={lon}&units=metric"

    response = requests.get(url).json()

    return response

# %%
weather_forecast(lat,lon)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1662357600,
#    'main': {'temp': 16.56,
#     'feels_like': 15.37,
#     'temp_min': 16.56,
#     'temp_max': 17.79,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 943,
#     'humidity': 42,
#     'temp_kf': -1.23},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.94, 'deg': 230, 'gust': 2.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-05 06:00:00'},
#   {'dt': 1662368400,
#    'main': {'temp': 18.24,
#     'feels_like': 17.16,
#     'temp_min': 18.24,
#     'temp_max': 21.61,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 945,
#     'humidity': 40,
#     'temp_kf': -3.37},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.89, 'deg': 223, 'gust': 6.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-05 09:00:00'},
#   {'dt': 1662379200,
#    'main': {'temp': 22.89,
#     'feels_like': 22.02,
#     'temp_min': 22.89,
#     'temp_max': 26.05,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 945,
#     'humidity': 30,
#     'temp_kf': -3.16},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.93, 'deg': 226, 'gust': 7.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-05 12:00:00'},
#   {'dt': 1662390000,
#    'main': {'temp': 27.92,
#     'feels_like': 26.66,
#     'temp_min': 27.92,
#     'temp_max': 27.92,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 944,
#     'humidity': 19,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 6.27, 'deg': 234, 'gust': 7.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-05 15:00:00'},
#   {'dt': 1662400800,
#    'main': {'temp': 26.47,
#     'feels_like': 26.47,
#     'temp_min': 26.47,
#     'temp_max': 26.47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 6.05, 'deg': 237, 'gust': 7.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-05 18:00:00'},
#   {'dt': 1662411600,
#    'main': {'temp': 23.41,
#     'feels_like': 22.64,
#     'temp_min': 23.41,
#     'temp_max': 23.41,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.1, 'deg': 242, 'gust': 6.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-05 21:00:00'},
#   {'dt': 1662422400,
#    'main': {'temp': 21.52,
#     'feels_like': 20.69,
#     'temp_min': 21.52,
#     'temp_max': 21.52,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 943,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.28, 'deg': 241, 'gust': 5.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-06 00:00:00'},
#   {'dt': 1662433200,
#    'main': {'temp': 19.8,
#     'feels_like': 18.96,
#     'temp_min': 19.8,
#     'temp_max': 19.8,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.65, 'deg': 226, 'gust': 4.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-06 03:00:00'},
#   {'dt': 1662444000,
#    'main': {'temp': 17.93,
#     'feels_like': 17.14,
#     'temp_min': 17.93,
#     'temp_max': 17.93,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 943,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 2.21, 'deg': 241, 'gust': 4.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 06:00:00'},
#   {'dt': 1662454800,
#    'main': {'temp': 22.02,
#     'feels_like': 21.37,
#     'temp_min': 22.02,
#     'temp_max': 22.02,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 944,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 3.93, 'deg': 229, 'gust': 5.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 09:00:00'},
#   {'dt': 1662465600,
#    'main': {'temp': 26.14,
#     'feels_like': 26.14,
#     'temp_min': 26.14,
#     'temp_max': 26.14,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 944,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 6.05, 'deg': 229, 'gust': 7.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 12:00:00'},
#   {'dt': 1662476400,
#    'main': {'temp': 28.34,
#     'feels_like': 27.17,
#     'temp_min': 28.34,
#     'temp_max': 28.34,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 942,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 6.79, 'deg': 230, 'gust': 8.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 15:00:00'},
#   {'dt': 1662487200,
#    'main': {'temp': 26.49,
#     'feels_like': 26.49,
#     'temp_min': 26.49,
#     'temp_max': 26.49,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 6.4, 'deg': 239, 'gust': 8.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-06 18:00:00'},
#   {'dt': 1662498000,
#    'main': {'temp': 23.48,
#     'feels_like': 22.72,
#     'temp_min': 23.48,
#     'temp_max': 23.48,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 3.86, 'deg': 242, 'gust': 6.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-06 21:00:00'},
#   {'dt': 1662508800,
#    'main': {'temp': 21.84,
#     'feels_like': 20.99,
#     'temp_min': 21.84,
#     'temp_max': 21.84,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 2.61, 'deg': 251, 'gust': 4.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 00:00:00'},
#   {'dt': 1662519600,
#    'main': {'temp': 20.05,
#     'feels_like': 19.13,
#     'temp_min': 20.05,
#     'temp_max': 20.05,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 1.3, 'deg': 222, 'gust': 2.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 03:00:00'},
#   {'dt': 1662530400,
#    'main': {'temp': 18.44,
#     'feels_like': 17.46,
#     'temp_min': 18.44,
#     'temp_max': 18.44,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 0.91, 'deg': 211, 'gust': 1.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 06:00:00'},
#   {'dt': 1662541200,
#    'main': {'temp': 21.63,
#     'feels_like': 20.74,
#     'temp_min': 21.63,
#     'temp_max': 21.63,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 3.19, 'deg': 232, 'gust': 5.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 09:00:00'},
#   {'dt': 1662552000,
#    'main': {'temp': 24.57,
#     'feels_like': 23.55,
#     'temp_min': 24.57,
#     'temp_max': 24.57,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 18,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 5.7, 'deg': 237, 'gust': 6.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 12:00:00'},
#   {'dt': 1662562800,
#    'main': {'temp': 26.7,
#     'feels_like': 25.71,
#     'temp_min': 26.7,
#     'temp_max': 26.7,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 940,
#     'humidity': 13,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.88, 'deg': 231, 'gust': 7.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 15:00:00'},
#   {'dt': 1662573600,
#    'main': {'temp': 25.96,
#     'feels_like': 25.96,
#     'temp_min': 25.96,
#     'temp_max': 25.96,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 940,
#     'humidity': 16,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.07, 'deg': 241, 'gust': 5.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-07 18:00:00'},
#   {'dt': 1662584400,
#    'main': {'temp': 22.9,
#     'feels_like': 21.98,
#     'temp_min': 22.9,
#     'temp_max': 22.9,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.23, 'deg': 296, 'gust': 5.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-07 21:00:00'},
#   {'dt': 1662595200,
#    'main': {'temp': 21.09,
#     'feels_like': 20.17,
#     'temp_min': 21.09,
#     'temp_max': 21.09,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 941,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 0.53, 'deg': 308, 'gust': 1.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 00:00:00'},
#   {'dt': 1662606000,
#    'main': {'temp': 19.33,
#     'feels_like': 18.42,
#     'temp_min': 19.33,
#     'temp_max': 19.33,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 940,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 0.83, 'deg': 101, 'gust': 1.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 03:00:00'},
#   {'dt': 1662616800,
#    'main': {'temp': 18.67,
#     'feels_like': 17.85,
#     'temp_min': 18.67,
#     'temp_max': 18.67,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 940,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.48, 'deg': 15, 'gust': 2.76},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 06:00:00'},
#   {'dt': 1662627600,
#    'main': {'temp': 19.51,
#     'feels_like': 18.8,
#     'temp_min': 19.51,
#     'temp_max': 19.51,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.77, 'deg': 75, 'gust': 1.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 09:00:00'},
#   {'dt': 1662638400,
#    'main': {'temp': 23.86,
#     'feels_like': 23.27,
#     'temp_min': 23.86,
#     'temp_max': 23.86,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 1.46, 'deg': 202, 'gust': 2.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 12:00:00'},
#   {'dt': 1662649200,
#    'main': {'temp': 25.72,
#     'feels_like': 25.21,
#     'temp_min': 25.72,
#     'temp_max': 25.72,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 2.89, 'deg': 239, 'gust': 3.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 15:00:00'},
#   {'dt': 1662660000,
#    'main': {'temp': 26,
#     'feels_like': 26,
#     'temp_min': 26,
#     'temp_max': 26,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 941,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 3.37, 'deg': 246, 'gust': 4.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-08 18:00:00'},
#   {'dt': 1662670800,
#    'main': {'temp': 24.04,
#     'feels_like': 23.7,
#     'temp_min': 24.04,
#     'temp_max': 24.04,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 2.92, 'deg': 307, 'gust': 4.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-08 21:00:00'},
#   {'dt': 1662681600,
#    'main': {'temp': 22.47,
#     'feels_like': 22.13,
#     'temp_min': 22.47,
#     'temp_max': 22.47,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 942,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 0.67, 'deg': 312, 'gust': 1.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 00:00:00'},
#   {'dt': 1662692400,
#    'main': {'temp': 20.71,
#     'feels_like': 20.35,
#     'temp_min': 20.71,
#     'temp_max': 20.71,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 0.19, 'deg': 82, 'gust': 2.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 03:00:00'},
#   {'dt': 1662703200,
#    'main': {'temp': 19.19,
#     'feels_like': 18.81,
#     'temp_min': 19.19,
#     'temp_max': 19.19,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 942,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 1.28, 'deg': 56, 'gust': 1.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 06:00:00'},
#   {'dt': 1662714000,
#    'main': {'temp': 22.96,
#     'feels_like': 22.62,
#     'temp_min': 22.96,
#     'temp_max': 22.96,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 0.17, 'deg': 321, 'gust': 1.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 09:00:00'},
#   {'dt': 1662724800,
#    'main': {'temp': 27.36,
#     'feels_like': 26.97,
#     'temp_min': 27.36,
#     'temp_max': 27.36,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 1.58, 'deg': 223, 'gust': 3.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 12:00:00'},
#   {'dt': 1662735600,
#    'main': {'temp': 31.14,
#     'feels_like': 29.35,
#     'temp_min': 31.14,
#     'temp_max': 31.14,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 942,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.56, 'deg': 249, 'gust': 5.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 15:00:00'},
#   {'dt': 1662746400,
#    'main': {'temp': 29.94,
#     'feels_like': 28.3,
#     'temp_min': 29.94,
#     'temp_max': 29.94,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 942,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 4.18, 'deg': 309, 'gust': 4.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-09 18:00:00'},
#   {'dt': 1662757200,
#    'main': {'temp': 27.36,
#     'feels_like': 26.53,
#     'temp_min': 27.36,
#     'temp_max': 27.36,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 943,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 2.31, 'deg': 2, 'gust': 3.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-09 21:00:00'},
#   {'dt': 1662768000,
#    'main': {'temp': 24.07,
#     'feels_like': 23.42,
#     'temp_min': 24.07,
#     'temp_max': 24.07,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 3.2, 'deg': 54, 'gust': 4.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-10 00:00:00'},
#   {'dt': 1662778800,
#    'main': {'temp': 22.44,
#     'feels_like': 21.71,
#     'temp_min': 22.44,
#     'temp_max': 22.44,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 943,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 3.27, 'deg': 43, 'gust': 4.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-10 03:00:00'}],
#  'city': {'id': 3117735,
#   'name': 'Madrid',
#   'coord': {'lat': 40.4167, 'lon': -3.7036},
#   'country': 'ES',
#   'population': 1000000,
#   'timezone': 7200,
#   'sunrise': 1662356757,
#   'sunset': 1662403297}}

# %%
# Out:
#   Input In [20]
#     https://pro.openweathermap.org/data/2.5/forecast/hourly?lat={lat}&lon={lon}&appid={API key}
#           ^
# SyntaxError: invalid syntax

# %%
# Out:
# <Response [404]>
